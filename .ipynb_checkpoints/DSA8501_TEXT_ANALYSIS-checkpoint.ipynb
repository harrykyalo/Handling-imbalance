# %%
#conda install -c conda-forge wordcloud

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from wordcloud import WordCloud
import nltk

#term frequency-inverse document frequenct
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
df=pd.read_csv('dsa8501.csv',delimiter=',',encoding='ISO-8859-1',header=None)

# %%
df.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df.describe()
# Out:
#                   0             1
# count  1.600000e+06  1.600000e+06
# mean   2.000000e+00  1.998818e+09
# std    2.000001e+00  1.935761e+08
# min    0.000000e+00  1.467810e+09
# 25%    0.000000e+00  1.956916e+09
# 50%    2.000000e+00  2.002102e+09
# 75%    4.000000e+00  2.177059e+09
# max    4.000000e+00  2.329206e+09

# %%
df[[0,5]].head()
# Out:
#    0                                                  5
# 0  0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  0  is upset that he can't update his Facebook by ...
# 2  0  @Kenichan I dived many times for the ball. Man...
# 3  0    my whole body feels itchy and like its on fire
# 4  0  @nationwideclass no, it's not behaving at all....

# %%
df=df.rename(columns={0:'target',5:'tweet'})
df=df.replace({'target':{4:1}})
df
# Out:
#          target           1                             2         3  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       1  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       1  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       1  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       1  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       1  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                        4                                              tweet
# ...

# %%
sns.countplot(x=df.target, palette='tab10').set(title='Tweets Distribution: positive(1) and negative (0)')
# Out:
# [Text(0.5, 1.0, 'Tweets Distribution: positive(1) and negative (0)')]

# %%
len(df.target)
# Out:
# 1600000

# %%
plt.figure(figsize=(10,8))
wordcloud=WordCloud(max_words=300,width=1200,height=800,background_color='white',collocations=False).generate("".join(df.tweet))
plt.grid(None)
plt.title("Worldcloud of tweets")
plt.axis('off')
plt.imshow(wordcloud)

# %% [markdown]
# ## Baseline:Logistic Regression with TF-IDF vectorizer

# %%
X=df['tweet']
y=np.array(df['target'])
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

print("Splitting done")
print("Shape of training set: "+ str(X_train.shape))
print("Shape of test set: "+ str(X_test.shape))
print("Count of training target values: "+str(np.unique(y_train,return_counts=True)))
print("Count of test target values: "+str(np.unique(y_test,return_counts=True)))
# Out:
# Splitting done
# Shape of training set: (1120000,)
# Shape of test set: (480000,)
# Count of training target values: (array([0, 1]), array([560639, 559361]))
# Count of test target values: (array([0, 1]), array([239361, 240639]))

# %%
classification_model=LogisticRegression(max_iter=1000,n_jobs=-1)
tfidconverter=TfidfVectorizer(max_features=500000,min_df=5,max_df=0.7,ngram_range=(1,2))

tfidconverter.fit(X_train)
X_train=tfidconverter.transform(X_train)
X_test=tfidconverter.transform(X_test)
classification_model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, n_jobs=-1)

# %%
X_train[0]
# Out:
# <1x303565 sparse matrix of type '<class 'numpy.float64'>'
# 	with 35 stored elements in Compressed Sparse Row format>

# %%
#prediction
prediction=classification_model.predict(X_test)

# %%
def model_Evaluate(model,X_test,y_test):
    #predict values for Test dataset
    y_pred=model.predict(X_test)
    #print the evaluation metrics for the dataset
    print(classification_report(y_test,y_pred))
    # compute and plot the confusion matrix
    cf_matrix=confusion_matrix(y_test,y_pred)
    categories=['Negative','Positive']
    group_names=['True_Neg','False Pos','False Neg','True Pos']
    group_percentages=['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]
    labels=[f'{v1}\n{v2}' for v1,v2 in zip(group_names,group_percentages)]
    labels=np.asarray(labels).reshape(2,2)
    
    sns.heatmap(cf_matrix,annot=labels,cmap='Blues',fmt='',
               xticklabels=categories,yticklabels=categories)
    plt.xlabel("Predicted values",fontdict={'size':14},labelpad=10)
    plt.xlabel("Actual values",fontdict={'size':14},labelpad=10)
    plt.title("Confusion Matrix",fontdict={'size':18},pad=20)

# %%
# Evaluation
model_Evaluate(classification_model,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82    239361
#            1       0.82      0.83      0.83    240639
#
#     accuracy                           0.82    480000
#    macro avg       0.82      0.82      0.82    480000
# weighted avg       0.82      0.82      0.82    480000

# %% [markdown]
# ## Test Other Data

# %%
model_Evaluate(classification_model,X_test,y_test)
X_test1=tfidconverter.transform(['We dont joke'])
classification_model.predict(X_test1)
sent_analysis=classification_model.predict(X_test1)
print(sent_analysis)
if sent_analysis==1:
    print('Positive sentiment')
else:
    print('Negative Sentiment')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82    239361
#            1       0.82      0.83      0.83    240639
#
#     accuracy                           0.82    480000
#    macro avg       0.82      0.82      0.82    480000
# weighted avg       0.82      0.82      0.82    480000
#
# [0]
# Negative Sentiment

# %% [markdown]
# # a word cloud is the simplest way to visualize the frequency of different words in a corpus
